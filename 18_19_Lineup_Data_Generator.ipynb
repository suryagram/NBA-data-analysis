# %%
import json
import requests
import pandas as pd
import numpy as np
import time
from datetime import datetime

# %%
with open('pbp_data/ATL-BKN-2019-03-10.json') as json_file:
    json_data = json.load(json_file)

# %%
len(json_data['periods'])
# Out:
# 4

# %%
lc_df_list = []
for i in range(len(json_data['periods'])):
    pbp_df_i = pd.io.json.json_normalize(json_data['periods'][i]['events'])
    pbp_df_i['period'] = (i+1)
    lineup_change_df_i = pbp_df_i[(pbp_df_i['event_type'] == 'lineupchange') | (pbp_df_i['event_type'] == 'endperiod')]
    lineup_change_df_i = lineup_change_df_i[['home_points', 'away_points', 'clock',
                                             'on_court.home.players', 'on_court.away.players', 'period']]
    lineup_change_df_i = lineup_change_df_i.drop_duplicates(subset=['home_points', 'away_points', 'clock', 'period'], keep='last')
    lc_df_list.append(lineup_change_df_i)
               

lc_df = pd.concat(lc_df_list)
lc_shift_df = lc_df.shift(-1)
lc_shift_df.columns = ['end_' + str(col) for col in lc_shift_df.columns]
lc_df.columns = ['start_' + str(col) for col in lc_df.columns]
lc_lagged_df = pd.concat([lc_df, lc_shift_df], axis=1)
lc_lagged_df = lc_lagged_df[pd.notnull(lc_lagged_df['start_on_court.home.players'])]

start_clock_tuple = lc_lagged_df['start_clock'].str.split(':', expand=True).astype(int)
lc_lagged_df['start_timedelta'] = pd.to_timedelta(start_clock_tuple[0], unit='m') + pd.to_timedelta(start_clock_tuple[1], unit='s')

end_clock_tuple = lc_lagged_df['end_clock'].str.split(':', expand=True).astype(int)
lc_lagged_df['end_timedelta'] = pd.to_timedelta(end_clock_tuple[0], unit='m') + pd.to_timedelta(end_clock_tuple[1], unit='s')

lc_lagged_df['oncourt_time'] = (lc_lagged_df['start_timedelta'] - lc_lagged_df['end_timedelta']).astype('timedelta64[s]')

lc_lagged_df['start_home_point_diff'] = lc_lagged_df['start_home_points'] - lc_lagged_df['start_away_points']
lc_lagged_df['end_home_point_diff'] = lc_lagged_df['end_home_points'] - lc_lagged_df['end_away_points']
lc_lagged_df['home_plus_minus'] = lc_lagged_df['end_home_point_diff'] - lc_lagged_df['start_home_point_diff']

lc_lagged_df['start_away_point_diff'] = -lc_lagged_df['start_home_point_diff']
lc_lagged_df['end_away_point_diff'] = -lc_lagged_df['end_home_point_diff']
lc_lagged_df['away_plus_minus'] = -lc_lagged_df['home_plus_minus']

lc_lagged_df = lc_lagged_df[['start_home_points', 'start_away_points', 'start_clock',
       'start_on_court.home.players', 'start_on_court.away.players',
       'start_period', 'end_home_points', 'end_away_points', 'end_clock',
        'end_period', 'start_timedelta', 'end_timedelta', 'oncourt_time',
       'start_home_point_diff', 'end_home_point_diff', 'home_plus_minus',
       'start_away_point_diff', 'end_away_point_diff', 'away_plus_minus']]

# %%
lc_lagged_df.head()
# Out:
#     start_home_points  start_away_points start_clock  \
# 1                   0                  0       12:00
# 53                 11                 10        6:52
# 66                 14                 13        5:45
# 80                 21                 17        4:06
# 94                 21                 20        2:42
#
#                           start_on_court.home.players  \
# 1   [{'full_name': 'Trae Young', 'jersey_number': ...
# 53  [{'full_name': 'Vince Carter', 'jersey_number'...
# 66  [{'full_name': 'Vince Carter', 'jersey_number'...
# 80  [{'full_name': 'Vince Carter', 'jersey_number'...
# 94  [{'full_name': 'Justin Anderson', 'jersey_numb...
#
#                           start_on_court.away.players  start_period  \
# 1   [{'full_name': 'Allen Crabbe', 'jersey_number'...             1
# 53  [{'full_name': 'Allen Crabbe', 'jersey_number'...             1
# 66  [{'full_name': 'D'Angelo Russell', 'jersey_num...             1
# 80  [{'full_name': 'DeMarre Carroll', 'jersey_numb...             1
# 94  [{'full_name': 'Allen Crabbe', 'jersey_number'...             1
#
#     end_home_points  end_away_points end_clock  end_period start_timedelta  \
# 1              11.0             10.0      6:52         1.0        00:12:00
# 53             14.0             13.0      5:45         1.0        00:06:52
# 66             21.0             17.0      4:06         1.0        00:05:45
# 80             21.0             20.0      2:42         1.0        00:04:06
# 94             23.0             26.0     00:00         1.0        00:02:42
#
#    end_timedelta  oncourt_time  start_home_point_diff  end_home_point_diff  \
# 1       00:06:52         308.0                      0                  1.0
# 53      00:05:45          67.0                      1                  1.0
# 66      00:04:06          99.0                      1                  4.0
# 80      00:02:42          84.0                      4                  1.0
# 94      00:00:00         162.0                      1                 -3.0
#
#     home_plus_minus  start_away_point_diff  end_away_point_diff  \
# 1               1.0                      0                 -1.0
# 53              0.0                     -1                 -1.0
# 66              3.0                     -1                 -4.0
# 80             -3.0                     -4                 -1.0
# 94             -4.0                     -1                  3.0
#
#     away_plus_minus
# 1              -1.0
# 53             -0.0
# 66             -3.0
# 80              3.0
# 94              4.0

# %%
for index, row in lc_lagged_df.iterrows():
    print("-----")
    i = 1
    for player in row['start_on_court.home.players']:
        print(player['full_name'])
        print(i)
        i = i + 1
# Out:
# -----
# Trae Young
# 1
# Kevin Huerter
# 2
# Alex Len
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Kevin Huerter
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Kevin Huerter
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Kent Bazemore
# 2
# Alex Len
# 3
# Jaylen Adams
# 4
# DeAndre' Bembry
# 5
# -----
# Justin Anderson
# 1
# Kent Bazemore
# 2
# Alex Len
# 3
# Jaylen Adams
# 4
# DeAndre' Bembry
# 5
# -----
# Kent Bazemore
# 1
# Alex Len
# 2
# Jaylen Adams
# 3
# John Collins
# 4
# DeAndre' Bembry
# 5
# -----
# Vince Carter
# 1
# Kent Bazemore
# 2
# Trae Young
# 3
# Kevin Huerter
# 4
# John Collins
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Kevin Huerter
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Kevin Huerter
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Kevin Huerter
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Kevin Huerter
# 3
# Alex Len
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Alex Len
# 3
# BJ Johnson
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Alex Len
# 3
# BJ Johnson
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Jaylen Adams
# 2
# BJ Johnson
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Jaylen Adams
# 2
# BJ Johnson
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Jaylen Adams
# 2
# BJ Johnson
# 3
# John Collins
# 4
# DeAndre' Bembry
# 5
# -----
# Vince Carter
# 1
# Justin Anderson
# 2
# Jaylen Adams
# 3
# BJ Johnson
# 4
# DeAndre' Bembry
# 5
# -----
# Trae Young
# 1
# Kevin Huerter
# 2
# Alex Len
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Kevin Huerter
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Tyler Zeller
# 3
# DeAndre' Bembry
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Kent Bazemore
# 2
# Tyler Zeller
# 3
# Jaylen Adams
# 4
# DeAndre' Bembry
# 5
# -----
# Vince Carter
# 1
# Kent Bazemore
# 2
# Tyler Zeller
# 3
# Jaylen Adams
# 4
# DeAndre' Bembry
# 5
# -----
# Justin Anderson
# 1
# Kent Bazemore
# 2
# Tyler Zeller
# 3
# Jaylen Adams
# 4
# DeAndre' Bembry
# 5
# -----
# Kevin Huerter
# 1
# Alex Len
# 2
# Jaylen Adams
# 3
# John Collins
# 4
# DeAndre' Bembry
# 5
# -----
# Kevin Huerter
# 1
# Alex Len
# 2
# Jaylen Adams
# 3
# John Collins
# 4
# DeAndre' Bembry
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Kevin Huerter
# 3
# Alex Len
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Kevin Huerter
# 3
# Alex Len
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Kent Bazemore
# 2
# Trae Young
# 3
# Alex Len
# 4
# Taurean Prince
# 5
# -----
# Kent Bazemore
# 1
# Trae Young
# 2
# Alex Len
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Kent Bazemore
# 2
# Trae Young
# 3
# Alex Len
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Kent Bazemore
# 2
# Trae Young
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Kent Bazemore
# 1
# Trae Young
# 2
# Alex Len
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Trae Young
# 1
# Kevin Huerter
# 2
# Alex Len
# 3
# John Collins
# 4
# Taurean Prince
# 5
# -----
# Vince Carter
# 1
# Trae Young
# 2
# Kevin Huerter
# 3
# John Collins
# 4
# Taurean Prince
# 5

# %%
lc_lagged_df
# Out:
#      start_home_points  start_away_points start_clock  \
# 1                    0                  0       12:00
# 53                  11                 10        6:52
# 66                  14                 13        5:45
# 80                  21                 17        4:06
# 94                  21                 20        2:42
# 1                   23                 26       12:00
# 22                  26                 31        9:42
# 41                  27                 32        7:59
# 52                  29                 32        7:27
# 63                  31                 34        6:55
# 67                  32                 35        6:46
# 80                  35                 38        5:39
# 86                  36                 38        5:32
# 104                 41                 46        3:50
# 110                 43                 47        3:28
# 131                 45                 52        1:46
# 146                 47                 56       00:26
# 1                   47                 56       12:00
# 52                  60                 69        7:35
# 63                  66                 70        7:00
# 77                  68                 70        5:58
# 104                 70                 74        3:28
# 131                 76                 81       00:57
# 0                   77                 83       12:00
# 22                  83                 88       10:05
# 37                  87                 91        8:51
# 39                  87                 91        8:46
# 67                  92                 94        6:54
# 85                  98                 99        5:43
# 95                  99                 99        5:11
# 103                102                 99        4:43
# 120                105                103        3:31
# 135                109                111        1:26
# 167                112                114       00:16
#
#                            start_on_court.home.players  \
# 1    [{'full_name': 'Trae Young', 'jersey_number': ...
# 53   [{'full_name': 'Vince Carter', 'jersey_number'...
# 66   [{'full_name': 'Vince Carter', 'jersey_number'...
# 80   [{'full_name': 'Vince Carter', 'jersey_number'...
# 94   [{'full_name': 'Justin Anderson', 'jersey_numb...
# 1    [{'full_name': 'Kent Bazemore', 'jersey_number...
# 22   [{'full_name': 'Vince Carter', 'jersey_number'...
# 41   [{'full_name': 'Vince Carter', 'jersey_number'...
# 52   [{'full_name': 'Vince Carter', 'jersey_number'...
# 63   [{'full_name': 'Vince Carter', 'jersey_number'...
# 67   [{'full_name': 'Vince Carter', 'jersey_number'...
# 80   [{'full_name': 'Vince Carter', 'jersey_number'...
# 86   [{'full_name': 'Vince Carter', 'jersey_number'...
# 104  [{'full_name': 'Vince Carter', 'jersey_number'...
# 110  [{'full_name': 'Vince Carter', 'jersey_number'...
# 131  [{'full_name': 'Vince Carter', 'jersey_number'...
# 146  [{'full_name': 'Vince Carter', 'jersey_number'...
# 1    [{'full_name': 'Trae Young', 'jersey_number': ...
# 52   [{'full_name': 'Vince Carter', 'jersey_number'...
# 63   [{'full_name': 'Vince Carter', 'jersey_number'...
# 77   [{'full_name': 'Vince Carter', 'jersey_number'...
# 104  [{'full_name': 'Vince Carter', 'jersey_number'...
# 131  [{'full_name': 'Justin Anderson', 'jersey_numb...
# 0    [{'full_name': 'Kevin Huerter', 'jersey_number...
# 22   [{'full_name': 'Kevin Huerter', 'jersey_number...
# 37   [{'full_name': 'Vince Carter', 'jersey_number'...
# 39   [{'full_name': 'Vince Carter', 'jersey_number'...
# 67   [{'full_name': 'Vince Carter', 'jersey_number'...
# 85   [{'full_name': 'Kent Bazemore', 'jersey_number...
# 95   [{'full_name': 'Vince Carter', 'jersey_number'...
# 103  [{'full_name': 'Vince Carter', 'jersey_number'...
# 120  [{'full_name': 'Kent Bazemore', 'jersey_number...
# 135  [{'full_name': 'Trae Young', 'jersey_number': ...
# 167  [{'full_name': 'Vince Carter', 'jersey_number'...
#
#                            start_on_court.away.players  start_period  \
# 1    [{'full_name': 'Allen Crabbe', 'jersey_number'...             1
# 53   [{'full_name': 'Allen Crabbe', 'jersey_number'...             1
# 66   [{'full_name': 'D'Angelo Russell', 'jersey_num...             1
# 80   [{'full_name': 'DeMarre Carroll', 'jersey_numb...             1
# 94   [{'full_name': 'Allen Crabbe', 'jersey_number'...             1
# 1    [{'full_name': 'Allen Crabbe', 'jersey_number'...             2
# 22   [{'full_name': 'Allen Crabbe', 'jersey_number'...             2
# 41   [{'full_name': 'Allen Crabbe', 'jersey_number'...             2
# 52   [{'full_name': 'Allen Crabbe', 'jersey_number'...             2
# 63   [{'full_name': 'D'Angelo Russell', 'jersey_num...             2
# 67   [{'full_name': 'D'Angelo Russell', 'jersey_num...             2
# 80   [{'full_name': 'D'Angelo Russell', 'jersey_num...             2
# 86   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...             2
# 104  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...             2
# 110  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...             2
# 131  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...             2
# 146  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...             2
# 1    [{'full_name': 'Allen Crabbe', 'jersey_number'...             3
# 52   [{'full_name': 'Allen Crabbe', 'jersey_number'...             3
# 63   [{'full_name': 'D'Angelo Russell', 'jersey_num...             3
# 77   [{'full_name': 'DeMarre Carroll', 'jersey_numb...             3
# 104  [{'full_name': 'Allen Crabbe', 'jersey_number'...             3
# 131  [{'full_name': 'Allen Crabbe', 'jersey_number'...             3
# 0    [{'full_name': 'Allen Crabbe', 'jersey_number'...             4
# 22   [{'full_name': 'Allen Crabbe', 'jersey_number'...             4
# 37   [{'full_name': 'Allen Crabbe', 'jersey_number'...             4
# 39   [{'full_name': 'Allen Crabbe', 'jersey_number'...             4
# 67   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...             4
# 85   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...             4
# 95   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...             4
# 103  [{'full_name': 'D'Angelo Russell', 'jersey_num...             4
# 120  [{'full_name': 'D'Angelo Russell', 'jersey_num...             4
# 135  [{'full_name': 'D'Angelo Russell', 'jersey_num...             4
# 167  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...             4
#
#      end_home_points  end_away_points end_clock  \
# 1               11.0             10.0      6:52
# 53              14.0             13.0      5:45
# 66              21.0             17.0      4:06
# 80              21.0             20.0      2:42
# 94              23.0             26.0     00:00
# 1               26.0             31.0      9:42
# 22              27.0             32.0      7:59
# 41              29.0             32.0      7:27
# 52              31.0             34.0      6:55
# 63              32.0             35.0      6:46
# 67              35.0             38.0      5:39
# 80              36.0             38.0      5:32
# 86              41.0             46.0      3:50
# 104             43.0             47.0      3:28
# 110             45.0             52.0      1:46
# 131             47.0             56.0     00:26
# 146             47.0             56.0     00:00
# 1               60.0             69.0      7:35
# 52              66.0             70.0      7:00
# 63              68.0             70.0      5:58
# 77              70.0             74.0      3:28
# 104             76.0             81.0     00:57
# 131             77.0             83.0     00:00
# 0               83.0             88.0     10:05
# 22              87.0             91.0      8:51
# 37              87.0             91.0      8:46
# 39              92.0             94.0      6:54
# 67              98.0             99.0      5:43
# 85              99.0             99.0      5:11
# 95             102.0             99.0      4:43
# 103            105.0            103.0      3:31
# 120            109.0            111.0      1:26
# 135            112.0            114.0     00:16
# 167            112.0            114.0     00:00
#
#                              end_on_court.home.players  \
# 1    [{'full_name': 'Vince Carter', 'jersey_number'...
# 53   [{'full_name': 'Vince Carter', 'jersey_number'...
# 66   [{'full_name': 'Vince Carter', 'jersey_number'...
# 80   [{'full_name': 'Justin Anderson', 'jersey_numb...
# 94                                                 NaN
# 1    [{'full_name': 'Vince Carter', 'jersey_number'...
# 22   [{'full_name': 'Vince Carter', 'jersey_number'...
# 41   [{'full_name': 'Vince Carter', 'jersey_number'...
# 52   [{'full_name': 'Vince Carter', 'jersey_number'...
# 63   [{'full_name': 'Vince Carter', 'jersey_number'...
# 67   [{'full_name': 'Vince Carter', 'jersey_number'...
# 80   [{'full_name': 'Vince Carter', 'jersey_number'...
# 86   [{'full_name': 'Vince Carter', 'jersey_number'...
# 104  [{'full_name': 'Vince Carter', 'jersey_number'...
# 110  [{'full_name': 'Vince Carter', 'jersey_number'...
# 131  [{'full_name': 'Vince Carter', 'jersey_number'...
# 146                                                NaN
# 1    [{'full_name': 'Vince Carter', 'jersey_number'...
# 52   [{'full_name': 'Vince Carter', 'jersey_number'...
# 63   [{'full_name': 'Vince Carter', 'jersey_number'...
# 77   [{'full_name': 'Vince Carter', 'jersey_number'...
# 104  [{'full_name': 'Justin Anderson', 'jersey_numb...
# 131                                                NaN
# 0    [{'full_name': 'Kevin Huerter', 'jersey_number...
# 22   [{'full_name': 'Vince Carter', 'jersey_number'...
# 37   [{'full_name': 'Vince Carter', 'jersey_number'...
# 39   [{'full_name': 'Vince Carter', 'jersey_number'...
# 67   [{'full_name': 'Kent Bazemore', 'jersey_number...
# 85   [{'full_name': 'Vince Carter', 'jersey_number'...
# 95   [{'full_name': 'Vince Carter', 'jersey_number'...
# 103  [{'full_name': 'Kent Bazemore', 'jersey_number...
# 120  [{'full_name': 'Trae Young', 'jersey_number': ...
# 135  [{'full_name': 'Vince Carter', 'jersey_number'...
# 167                                                NaN
#
#                              end_on_court.away.players  end_period  \
# 1    [{'full_name': 'Allen Crabbe', 'jersey_number'...         1.0
# 53   [{'full_name': 'D'Angelo Russell', 'jersey_num...         1.0
# 66   [{'full_name': 'DeMarre Carroll', 'jersey_numb...         1.0
# 80   [{'full_name': 'Allen Crabbe', 'jersey_number'...         1.0
# 94                                                 NaN         1.0
# 1    [{'full_name': 'Allen Crabbe', 'jersey_number'...         2.0
# 22   [{'full_name': 'Allen Crabbe', 'jersey_number'...         2.0
# 41   [{'full_name': 'Allen Crabbe', 'jersey_number'...         2.0
# 52   [{'full_name': 'D'Angelo Russell', 'jersey_num...         2.0
# 63   [{'full_name': 'D'Angelo Russell', 'jersey_num...         2.0
# 67   [{'full_name': 'D'Angelo Russell', 'jersey_num...         2.0
# 80   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...         2.0
# 86   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...         2.0
# 104  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...         2.0
# 110  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...         2.0
# 131  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...         2.0
# 146                                                NaN         2.0
# 1    [{'full_name': 'Allen Crabbe', 'jersey_number'...         3.0
# 52   [{'full_name': 'D'Angelo Russell', 'jersey_num...         3.0
# 63   [{'full_name': 'DeMarre Carroll', 'jersey_numb...         3.0
# 77   [{'full_name': 'Allen Crabbe', 'jersey_number'...         3.0
# 104  [{'full_name': 'Allen Crabbe', 'jersey_number'...         3.0
# 131                                                NaN         3.0
# 0    [{'full_name': 'Allen Crabbe', 'jersey_number'...         4.0
# 22   [{'full_name': 'Allen Crabbe', 'jersey_number'...         4.0
# 37   [{'full_name': 'Allen Crabbe', 'jersey_number'...         4.0
# 39   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...         4.0
# 67   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...         4.0
# 85   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...         4.0
# 95   [{'full_name': 'D'Angelo Russell', 'jersey_num...         4.0
# 103  [{'full_name': 'D'Angelo Russell', 'jersey_num...         4.0
# 120  [{'full_name': 'D'Angelo Russell', 'jersey_num...         4.0
# 135  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...         4.0
# 167                                                NaN         4.0
#
#     start_timedelta end_timedelta  oncourt_time
# 1          00:12:00      00:06:52         308.0
# 53         00:06:52      00:05:45          67.0
# 66         00:05:45      00:04:06          99.0
# 80         00:04:06      00:02:42          84.0
# 94         00:02:42      00:00:00         162.0
# 1          00:12:00      00:09:42         138.0
# 22         00:09:42      00:07:59         103.0
# 41         00:07:59      00:07:27          32.0
# 52         00:07:27      00:06:55          32.0
# 63         00:06:55      00:06:46           9.0
# 67         00:06:46      00:05:39          67.0
# 80         00:05:39      00:05:32           7.0
# 86         00:05:32      00:03:50         102.0
# 104        00:03:50      00:03:28          22.0
# 110        00:03:28      00:01:46         102.0
# 131        00:01:46      00:00:26          80.0
# 146        00:00:26      00:00:00          26.0
# 1          00:12:00      00:07:35         265.0
# 52         00:07:35      00:07:00          35.0
# 63         00:07:00      00:05:58          62.0
# 77         00:05:58      00:03:28         150.0
# 104        00:03:28      00:00:57         151.0
# 131        00:00:57      00:00:00          57.0
# 0          00:12:00      00:10:05         115.0
# 22         00:10:05      00:08:51          74.0
# 37         00:08:51      00:08:46           5.0
# 39         00:08:46      00:06:54         112.0
# 67         00:06:54      00:05:43          71.0
# 85         00:05:43      00:05:11          32.0
# 95         00:05:11      00:04:43          28.0
# 103        00:04:43      00:03:31          72.0
# 120        00:03:31      00:01:26         125.0
# 135        00:01:26      00:00:16          70.0
# 167        00:00:16      00:00:00          16.0

# %%
lineup_change_df = pbp_df[pbp_df['event_type'] == 'lineupchange']
lineup_change_df.head()
lineup_change_df[['home_points', 'away_points', 'clock', 'on_court.home.players', 'on_court.away.players', 'period']].head()
# Out:
#     home_points  away_points  clock  \
# 0             0            0  12:00
# 1             0            0  12:00
# 52           11           10   6:52
# 53           11           10   6:52
# 66           14           13   5:45
#
#                                 on_court.home.players  \
# 0   [{'full_name': 'Trae Young', 'jersey_number': ...
# 1   [{'full_name': 'Trae Young', 'jersey_number': ...
# 52  [{'full_name': 'Trae Young', 'jersey_number': ...
# 53  [{'full_name': 'Vince Carter', 'jersey_number'...
# 66  [{'full_name': 'Vince Carter', 'jersey_number'...
#
#                                 on_court.away.players  period
# 0   [{'full_name': 'Allen Crabbe', 'jersey_number'...       1
# 1   [{'full_name': 'Allen Crabbe', 'jersey_number'...       1
# 52  [{'full_name': 'Allen Crabbe', 'jersey_number'...       1
# 53  [{'full_name': 'Allen Crabbe', 'jersey_number'...       1
# 66  [{'full_name': 'D'Angelo Russell', 'jersey_num...       1

# %%
end_result_dict = {
    'home_points': json_data['home']['points'],
    'away_points': json_data['away']['points'],
    'clock': '00:00',
    'on_court.home.players': None,
    'on_court.away.players' : None,
    'period': 4
}
end_result_df = pd.DataFrame.from_dict(end_result_dict, orient='index')
end_result_df.transpose()
# Out:
#   home_points away_points  clock on_court.home.players on_court.away.players  \
# 0         112         114  00:00                  None                  None
#
#   period
# 0      4

# %%
for index, row in lineup_change_df.iterrows():
    print("-------")
    print(row['on_court.away.players'][0]['full_name'])
    for i in row['on_court.away.players']:
        print(i['full_name'])
# Out:
# -------
# Allen Crabbe
# Allen Crabbe
# Rodions Kurucs
# D'Angelo Russell
# Joe Harris
# Jarrett Allen
# -------
# Allen Crabbe
# Allen Crabbe
# Rodions Kurucs
# D'Angelo Russell
# Joe Harris
# Jarrett Allen
# -------
# Allen Crabbe
# Allen Crabbe
# D'Angelo Russell
# DeMarre Carroll
# Joe Harris
# Jarrett Allen
# -------
# Allen Crabbe
# Allen Crabbe
# D'Angelo Russell
# DeMarre Carroll
# Joe Harris
# Jarrett Allen
# -------
# D'Angelo Russell
# D'Angelo Russell
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# DeMarre Carroll
# DeMarre Carroll
# Spencer Dinwiddie
# Caris LeVert
# Ed Davis
# Joe Harris
# -------
# DeMarre Carroll
# DeMarre Carroll
# Spencer Dinwiddie
# Caris LeVert
# Ed Davis
# Joe Harris
# -------
# DeMarre Carroll
# DeMarre Carroll
# Spencer Dinwiddie
# Caris LeVert
# Ed Davis
# Joe Harris
# -------
# Allen Crabbe
# Allen Crabbe
# DeMarre Carroll
# Spencer Dinwiddie
# Caris LeVert
# Ed Davis
# -------
# Allen Crabbe
# Allen Crabbe
# D'Angelo Russell
# DeMarre Carroll
# Caris LeVert
# Ed Davis
# -------
# Allen Crabbe
# Allen Crabbe
# D'Angelo Russell
# DeMarre Carroll
# Caris LeVert
# Ed Davis
# -------
# Allen Crabbe
# Allen Crabbe
# D'Angelo Russell
# DeMarre Carroll
# Caris LeVert
# Ed Davis
# -------
# Allen Crabbe
# Allen Crabbe
# D'Angelo Russell
# DeMarre Carroll
# Caris LeVert
# Ed Davis
# -------
# Allen Crabbe
# Allen Crabbe
# D'Angelo Russell
# DeMarre Carroll
# Spencer Dinwiddie
# Ed Davis
# -------
# D'Angelo Russell
# D'Angelo Russell
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# D'Angelo Russell
# D'Angelo Russell
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# D'Angelo Russell
# D'Angelo Russell
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# Rodions Kurucs
# Rodions Kurucs
# D'Angelo Russell
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# Rodions Kurucs
# Rodions Kurucs
# D'Angelo Russell
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# Rodions Kurucs
# Rodions Kurucs
# Spencer Dinwiddie
# Caris LeVert
# Joe Harris
# Jarrett Allen
# -------
# Rodions Kurucs
# Rodions Kurucs
# Spencer Dinwiddie
# Caris LeVert
# Joe Harris
# Jarrett Allen
# -------
# Rodions Kurucs
# Rodions Kurucs
# Spencer Dinwiddie
# Caris LeVert
# Joe Harris
# Jarrett Allen
# -------
# Allen Crabbe
# Allen Crabbe
# Rodions Kurucs
# D'Angelo Russell
# Joe Harris
# Jarrett Allen
# -------
# Allen Crabbe
# Allen Crabbe
# Rodions Kurucs
# D'Angelo Russell
# Joe Harris
# Jarrett Allen
# -------
# Allen Crabbe
# Allen Crabbe
# D'Angelo Russell
# DeMarre Carroll
# Joe Harris
# Jarrett Allen
# -------
# Allen Crabbe
# Allen Crabbe
# D'Angelo Russell
# DeMarre Carroll
# Joe Harris
# Jarrett Allen
# -------
# D'Angelo Russell
# D'Angelo Russell
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# D'Angelo Russell
# D'Angelo Russell
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# DeMarre Carroll
# DeMarre Carroll
# Spencer Dinwiddie
# Caris LeVert
# Ed Davis
# Joe Harris
# -------
# DeMarre Carroll
# DeMarre Carroll
# Spencer Dinwiddie
# Caris LeVert
# Ed Davis
# Joe Harris
# -------
# Allen Crabbe
# Allen Crabbe
# DeMarre Carroll
# Spencer Dinwiddie
# Caris LeVert
# Ed Davis
# -------
# Allen Crabbe
# Allen Crabbe
# DeMarre Carroll
# Spencer Dinwiddie
# Caris LeVert
# Ed Davis
# -------
# Allen Crabbe
# Allen Crabbe
# DeMarre Carroll
# Spencer Dinwiddie
# Caris LeVert
# Ed Davis
# -------
# Allen Crabbe
# Allen Crabbe
# Rodions Kurucs
# Spencer Dinwiddie
# Caris LeVert
# Ed Davis
# -------
# Allen Crabbe
# Allen Crabbe
# Rodions Kurucs
# D'Angelo Russell
# Spencer Dinwiddie
# Jarrett Allen
# -------
# Allen Crabbe
# Allen Crabbe
# Rodions Kurucs
# D'Angelo Russell
# Spencer Dinwiddie
# Jarrett Allen
# -------
# Allen Crabbe
# Allen Crabbe
# Rodions Kurucs
# D'Angelo Russell
# Joe Harris
# Jarrett Allen
# -------
# Rodions Kurucs
# Rodions Kurucs
# D'Angelo Russell
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# Rodions Kurucs
# Rodions Kurucs
# D'Angelo Russell
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# Rodions Kurucs
# Rodions Kurucs
# D'Angelo Russell
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# Rodions Kurucs
# Rodions Kurucs
# D'Angelo Russell
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# D'Angelo Russell
# D'Angelo Russell
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# D'Angelo Russell
# D'Angelo Russell
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# D'Angelo Russell
# D'Angelo Russell
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# D'Angelo Russell
# D'Angelo Russell
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# Rodions Kurucs
# Rodions Kurucs
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen
# -------
# Rodions Kurucs
# Rodions Kurucs
# DeMarre Carroll
# Spencer Dinwiddie
# Joe Harris
# Jarrett Allen

# %%
lc_df = pd.concat([lineup_change_df[['home_points', 'away_points', 'clock', 'on_court.home.players', 'on_court.away.players', 'period']], end_result_df.transpose()])
lc_df
# Out:
#     home_points away_points  clock  \
# 0             0           0  12:00
# 1             0           0  12:00
# 52           11          10   6:52
# 53           11          10   6:52
# 66           14          13   5:45
# 79           21          17   4:06
# 80           21          17   4:06
# 93           21          20   2:42
# 94           21          20   2:42
# 0            23          26  12:00
# 1            23          26  12:00
# 22           26          31   9:42
# 41           27          32   7:59
# 52           29          32   7:27
# 63           31          34   6:55
# 67           32          35   6:46
# 80           35          38   5:39
# 86           36          38   5:32
# 104          41          46   3:50
# 110          43          47   3:28
# 131          45          52   1:46
# 146          47          56  00:26
# 0            47          56  12:00
# 1            47          56  12:00
# 51           60          69   7:35
# 52           60          69   7:35
# 62           66          70   7:00
# 63           66          70   7:00
# 76           68          70   5:58
# 77           68          70   5:58
# 104          70          74   3:28
# 131          76          81  00:57
# 0            77          83  12:00
# 22           83          88  10:05
# 36           87          91   8:51
# 37           87          91   8:51
# 39           87          91   8:46
# 66           92          94   6:54
# 67           92          94   6:54
# 85           98          99   5:43
# 95           99          99   5:11
# 102         102          99   4:43
# 103         102          99   4:43
# 120         105         103   3:31
# 135         109         111   1:26
# 166         112         114  00:16
# 167         112         114  00:16
# 0           112         114  00:00
#
#                                  on_court.home.players  \
# 0    [{'full_name': 'Trae Young', 'jersey_number': ...
# 1    [{'full_name': 'Trae Young', 'jersey_number': ...
# 52   [{'full_name': 'Trae Young', 'jersey_number': ...
# 53   [{'full_name': 'Vince Carter', 'jersey_number'...
# 66   [{'full_name': 'Vince Carter', 'jersey_number'...
# 79   [{'full_name': 'Vince Carter', 'jersey_number'...
# 80   [{'full_name': 'Vince Carter', 'jersey_number'...
# 93   [{'full_name': 'Justin Anderson', 'jersey_numb...
# 94   [{'full_name': 'Justin Anderson', 'jersey_numb...
# 0    [{'full_name': 'Justin Anderson', 'jersey_numb...
# 1    [{'full_name': 'Kent Bazemore', 'jersey_number...
# 22   [{'full_name': 'Vince Carter', 'jersey_number'...
# 41   [{'full_name': 'Vince Carter', 'jersey_number'...
# 52   [{'full_name': 'Vince Carter', 'jersey_number'...
# 63   [{'full_name': 'Vince Carter', 'jersey_number'...
# 67   [{'full_name': 'Vince Carter', 'jersey_number'...
# 80   [{'full_name': 'Vince Carter', 'jersey_number'...
# 86   [{'full_name': 'Vince Carter', 'jersey_number'...
# 104  [{'full_name': 'Vince Carter', 'jersey_number'...
# 110  [{'full_name': 'Vince Carter', 'jersey_number'...
# 131  [{'full_name': 'Vince Carter', 'jersey_number'...
# 146  [{'full_name': 'Vince Carter', 'jersey_number'...
# 0    [{'full_name': 'Vince Carter', 'jersey_number'...
# 1    [{'full_name': 'Trae Young', 'jersey_number': ...
# 51   [{'full_name': 'Trae Young', 'jersey_number': ...
# 52   [{'full_name': 'Vince Carter', 'jersey_number'...
# 62   [{'full_name': 'Vince Carter', 'jersey_number'...
# 63   [{'full_name': 'Vince Carter', 'jersey_number'...
# 76   [{'full_name': 'Vince Carter', 'jersey_number'...
# 77   [{'full_name': 'Vince Carter', 'jersey_number'...
# 104  [{'full_name': 'Vince Carter', 'jersey_number'...
# 131  [{'full_name': 'Justin Anderson', 'jersey_numb...
# 0    [{'full_name': 'Kevin Huerter', 'jersey_number...
# 22   [{'full_name': 'Kevin Huerter', 'jersey_number...
# 36   [{'full_name': 'Kevin Huerter', 'jersey_number...
# 37   [{'full_name': 'Vince Carter', 'jersey_number'...
# 39   [{'full_name': 'Vince Carter', 'jersey_number'...
# 66   [{'full_name': 'Vince Carter', 'jersey_number'...
# 67   [{'full_name': 'Vince Carter', 'jersey_number'...
# 85   [{'full_name': 'Kent Bazemore', 'jersey_number...
# 95   [{'full_name': 'Vince Carter', 'jersey_number'...
# 102  [{'full_name': 'Vince Carter', 'jersey_number'...
# 103  [{'full_name': 'Vince Carter', 'jersey_number'...
# 120  [{'full_name': 'Kent Bazemore', 'jersey_number...
# 135  [{'full_name': 'Trae Young', 'jersey_number': ...
# 166  [{'full_name': 'Trae Young', 'jersey_number': ...
# 167  [{'full_name': 'Vince Carter', 'jersey_number'...
# 0                                                 None
#
#                                  on_court.away.players period
# 0    [{'full_name': 'Allen Crabbe', 'jersey_number'...      1
# 1    [{'full_name': 'Allen Crabbe', 'jersey_number'...      1
# 52   [{'full_name': 'Allen Crabbe', 'jersey_number'...      1
# 53   [{'full_name': 'Allen Crabbe', 'jersey_number'...      1
# 66   [{'full_name': 'D'Angelo Russell', 'jersey_num...      1
# 79   [{'full_name': 'DeMarre Carroll', 'jersey_numb...      1
# 80   [{'full_name': 'DeMarre Carroll', 'jersey_numb...      1
# 93   [{'full_name': 'DeMarre Carroll', 'jersey_numb...      1
# 94   [{'full_name': 'Allen Crabbe', 'jersey_number'...      1
# 0    [{'full_name': 'Allen Crabbe', 'jersey_number'...      2
# 1    [{'full_name': 'Allen Crabbe', 'jersey_number'...      2
# 22   [{'full_name': 'Allen Crabbe', 'jersey_number'...      2
# 41   [{'full_name': 'Allen Crabbe', 'jersey_number'...      2
# 52   [{'full_name': 'Allen Crabbe', 'jersey_number'...      2
# 63   [{'full_name': 'D'Angelo Russell', 'jersey_num...      2
# 67   [{'full_name': 'D'Angelo Russell', 'jersey_num...      2
# 80   [{'full_name': 'D'Angelo Russell', 'jersey_num...      2
# 86   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...      2
# 104  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...      2
# 110  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...      2
# 131  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...      2
# 146  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...      2
# 0    [{'full_name': 'Allen Crabbe', 'jersey_number'...      3
# 1    [{'full_name': 'Allen Crabbe', 'jersey_number'...      3
# 51   [{'full_name': 'Allen Crabbe', 'jersey_number'...      3
# 52   [{'full_name': 'Allen Crabbe', 'jersey_number'...      3
# 62   [{'full_name': 'D'Angelo Russell', 'jersey_num...      3
# 63   [{'full_name': 'D'Angelo Russell', 'jersey_num...      3
# 76   [{'full_name': 'DeMarre Carroll', 'jersey_numb...      3
# 77   [{'full_name': 'DeMarre Carroll', 'jersey_numb...      3
# 104  [{'full_name': 'Allen Crabbe', 'jersey_number'...      3
# 131  [{'full_name': 'Allen Crabbe', 'jersey_number'...      3
# 0    [{'full_name': 'Allen Crabbe', 'jersey_number'...      4
# 22   [{'full_name': 'Allen Crabbe', 'jersey_number'...      4
# 36   [{'full_name': 'Allen Crabbe', 'jersey_number'...      4
# 37   [{'full_name': 'Allen Crabbe', 'jersey_number'...      4
# 39   [{'full_name': 'Allen Crabbe', 'jersey_number'...      4
# 66   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...      4
# 67   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...      4
# 85   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...      4
# 95   [{'full_name': 'Rodions Kurucs', 'jersey_numbe...      4
# 102  [{'full_name': 'D'Angelo Russell', 'jersey_num...      4
# 103  [{'full_name': 'D'Angelo Russell', 'jersey_num...      4
# 120  [{'full_name': 'D'Angelo Russell', 'jersey_num...      4
# 135  [{'full_name': 'D'Angelo Russell', 'jersey_num...      4
# 166  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...      4
# 167  [{'full_name': 'Rodions Kurucs', 'jersey_numbe...      4
# 0                                                 None      4

# %%
lc_df = lc_df.drop_duplicates(subset=['home_points', 'away_points', 'clock', 'period'], keep='last')

# %%
lc_shift_df = lc_df.shift(-1)
lc_shift_df.head()
# Out:
#    home_points away_points  clock  \
# 1           11          10   6:52
# 53          14          13   5:45
# 66          21          17   4:06
# 80          21          20   2:42
# 94          23          26  12:00
#
#                                 on_court.home.players  \
# 1   [{'full_name': 'Vince Carter', 'jersey_number'...
# 53  [{'full_name': 'Vince Carter', 'jersey_number'...
# 66  [{'full_name': 'Vince Carter', 'jersey_number'...
# 80  [{'full_name': 'Justin Anderson', 'jersey_numb...
# 94  [{'full_name': 'Kent Bazemore', 'jersey_number...
#
#                                 on_court.away.players period
# 1   [{'full_name': 'Allen Crabbe', 'jersey_number'...      1
# 53  [{'full_name': 'D'Angelo Russell', 'jersey_num...      1
# 66  [{'full_name': 'DeMarre Carroll', 'jersey_numb...      1
# 80  [{'full_name': 'Allen Crabbe', 'jersey_number'...      1
# 94  [{'full_name': 'Allen Crabbe', 'jersey_number'...      2

# %%
lc_lagged_df = pd.concat([lc_df, lc_shift_df], axis=1)
lc_lagged_df.head()
# Out:
#    home_points away_points  clock  \
# 1            0           0  12:00
# 53          11          10   6:52
# 66          14          13   5:45
# 80          21          17   4:06
# 94          21          20   2:42
#
#                                 on_court.home.players  \
# 1   [{'full_name': 'Trae Young', 'jersey_number': ...
# 53  [{'full_name': 'Vince Carter', 'jersey_number'...
# 66  [{'full_name': 'Vince Carter', 'jersey_number'...
# 80  [{'full_name': 'Vince Carter', 'jersey_number'...
# 94  [{'full_name': 'Justin Anderson', 'jersey_numb...
#
#                                 on_court.away.players period home_points  \
# 1   [{'full_name': 'Allen Crabbe', 'jersey_number'...      1          11
# 53  [{'full_name': 'Allen Crabbe', 'jersey_number'...      1          14
# 66  [{'full_name': 'D'Angelo Russell', 'jersey_num...      1          21
# 80  [{'full_name': 'DeMarre Carroll', 'jersey_numb...      1          21
# 94  [{'full_name': 'Allen Crabbe', 'jersey_number'...      1          23
#
#    away_points  clock                              on_court.home.players  \
# 1           10   6:52  [{'full_name': 'Vince Carter', 'jersey_number'...
# 53          13   5:45  [{'full_name': 'Vince Carter', 'jersey_number'...
# 66          17   4:06  [{'full_name': 'Vince Carter', 'jersey_number'...
# 80          20   2:42  [{'full_name': 'Justin Anderson', 'jersey_numb...
# 94          26  12:00  [{'full_name': 'Kent Bazemore', 'jersey_number...
#
#                                 on_court.away.players period
# 1   [{'full_name': 'Allen Crabbe', 'jersey_number'...      1
# 53  [{'full_name': 'D'Angelo Russell', 'jersey_num...      1
# 66  [{'full_name': 'DeMarre Carroll', 'jersey_numb...      1
# 80  [{'full_name': 'Allen Crabbe', 'jersey_number'...      1
# 94  [{'full_name': 'Allen Crabbe', 'jersey_number'...      2

# %%
lc_lagged_df.head()
# Out:
#     start_home_points  start_away_points start_clock  \
# 1                   0                  0       12:00
# 53                 11                 10        6:52
# 66                 14                 13        5:45
# 80                 21                 17        4:06
# 94                 21                 20        2:42
#
#                           start_on_court.home.players  \
# 1   [{'full_name': 'Trae Young', 'jersey_number': ...
# 53  [{'full_name': 'Vince Carter', 'jersey_number'...
# 66  [{'full_name': 'Vince Carter', 'jersey_number'...
# 80  [{'full_name': 'Vince Carter', 'jersey_number'...
# 94  [{'full_name': 'Justin Anderson', 'jersey_numb...
#
#                           start_on_court.away.players  start_period  \
# 1   [{'full_name': 'Allen Crabbe', 'jersey_number'...             1
# 53  [{'full_name': 'Allen Crabbe', 'jersey_number'...             1
# 66  [{'full_name': 'D'Angelo Russell', 'jersey_num...             1
# 80  [{'full_name': 'DeMarre Carroll', 'jersey_numb...             1
# 94  [{'full_name': 'Allen Crabbe', 'jersey_number'...             1
#
#     end_home_points  end_away_points end_clock  end_period start_timedelta  \
# 1              11.0             10.0      6:52         1.0        00:12:00
# 53             14.0             13.0      5:45         1.0        00:06:52
# 66             21.0             17.0      4:06         1.0        00:05:45
# 80             21.0             20.0      2:42         1.0        00:04:06
# 94             23.0             26.0     00:00         1.0        00:02:42
#
#    end_timedelta  oncourt_time  start_home_point_diff  end_home_point_diff  \
# 1       00:06:52         308.0                      0                  1.0
# 53      00:05:45          67.0                      1                  1.0
# 66      00:04:06          99.0                      1                  4.0
# 80      00:02:42          84.0                      4                  1.0
# 94      00:00:00         162.0                      1                 -3.0
#
#     home_plus_minus  start_away_point_diff  end_away_point_diff  \
# 1               1.0                      0                 -1.0
# 53              0.0                     -1                 -1.0
# 66              3.0                     -1                 -4.0
# 80             -3.0                     -4                 -1.0
# 94             -4.0                     -1                  3.0
#
#     away_plus_minus
# 1              -1.0
# 53             -0.0
# 66             -3.0
# 80              3.0
# 94              4.0

# %%
lc_lagged_df[]

for index, row in lc_lagged_df.iterrows():
    row[]


    
    

for i in lc_lagged_df['start_on_court.home.players']:
    players = []
    for j in i:
        players.append(j['full_name'])
    print(players)
# Out:
# ['Trae Young', 'Kevin Huerter', 'Alex Len', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Trae Young', 'Kevin Huerter', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Trae Young', 'Kevin Huerter', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Kent Bazemore', 'Alex Len', 'Jaylen Adams', "DeAndre' Bembry"]
# ['Justin Anderson', 'Kent Bazemore', 'Alex Len', 'Jaylen Adams', "DeAndre' Bembry"]
# ['Kent Bazemore', 'Alex Len', 'Jaylen Adams', 'John Collins', "DeAndre' Bembry"]
# ['Vince Carter', 'Kent Bazemore', 'Trae Young', 'Kevin Huerter', 'John Collins']
# ['Vince Carter', 'Trae Young', 'Kevin Huerter', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Trae Young', 'Kevin Huerter', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Trae Young', 'Kevin Huerter', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Trae Young', 'Kevin Huerter', 'Alex Len', 'Taurean Prince']
# ['Vince Carter', 'Trae Young', 'Alex Len', 'BJ Johnson', 'Taurean Prince']
# ['Vince Carter', 'Trae Young', 'Alex Len', 'BJ Johnson', 'Taurean Prince']
# ['Vince Carter', 'Jaylen Adams', 'BJ Johnson', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Jaylen Adams', 'BJ Johnson', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Jaylen Adams', 'BJ Johnson', 'John Collins', "DeAndre' Bembry"]
# ['Vince Carter', 'Justin Anderson', 'Jaylen Adams', 'BJ Johnson', "DeAndre' Bembry"]
# ['Trae Young', 'Kevin Huerter', 'Alex Len', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Trae Young', 'Kevin Huerter', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Trae Young', 'Tyler Zeller', "DeAndre' Bembry", 'Taurean Prince']
# ['Vince Carter', 'Kent Bazemore', 'Tyler Zeller', 'Jaylen Adams', "DeAndre' Bembry"]
# ['Vince Carter', 'Kent Bazemore', 'Tyler Zeller', 'Jaylen Adams', "DeAndre' Bembry"]
# ['Justin Anderson', 'Kent Bazemore', 'Tyler Zeller', 'Jaylen Adams', "DeAndre' Bembry"]
# ['Kevin Huerter', 'Alex Len', 'Jaylen Adams', 'John Collins', "DeAndre' Bembry"]
# ['Kevin Huerter', 'Alex Len', 'Jaylen Adams', 'John Collins', "DeAndre' Bembry"]
# ['Vince Carter', 'Trae Young', 'Kevin Huerter', 'Alex Len', 'Taurean Prince']
# ['Vince Carter', 'Trae Young', 'Kevin Huerter', 'Alex Len', 'Taurean Prince']
# ['Vince Carter', 'Kent Bazemore', 'Trae Young', 'Alex Len', 'Taurean Prince']
# ['Kent Bazemore', 'Trae Young', 'Alex Len', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Kent Bazemore', 'Trae Young', 'Alex Len', 'Taurean Prince']
# ['Vince Carter', 'Kent Bazemore', 'Trae Young', 'John Collins', 'Taurean Prince']
# ['Kent Bazemore', 'Trae Young', 'Alex Len', 'John Collins', 'Taurean Prince']
# ['Trae Young', 'Kevin Huerter', 'Alex Len', 'John Collins', 'Taurean Prince']
# ['Vince Carter', 'Trae Young', 'Kevin Huerter', 'John Collins', 'Taurean Prince']
